# %% [markdown]
# # Part A. Bag of Words

# %% [markdown]
# ## Execise A1: Download the super villain pages

# %%
import urllib
import json

#Make request for category members, save data to file and return as dictionary datastructure
def wiki_to_json_dict(url):
    request = urllib.request.urlopen(url)
    markup = request.read()
    output_file = open('data.json', 'wb')
    output_file.write(markup)
    output_file.close()
    json_data = open('data.json', 'r')
    data = json.load(json_data)
    json_data.close()
    return data

#Take category dictionary and return list of dictionaries with each element
def get_category_members(response_dict):
    return response_dict['query']['categorymembers']

#Take element dictionary and return the title only
def extract_category_member_title(el):
    return el['title']

#Downloads a wiki page and saves its contents to a file
def download_page_and_save_to_file(title, folder):
    safe_title = urllib.parse.quote(title)
    response = urllib.request.urlopen('http://en.wikipedia.org/w/api.php?action=query&titles='+safe_title+'&prop=revisions&rvprop=content&format=json')
    markup = response.read()
    import os
    path = os.path.join(folder, title)
    output_file = open(path, 'wb')
    output_file.write(markup)
    output_file.close()

#Scrap the relevant category and put data into appropriate datastructure
address1 = 'http://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:Marvel_Comics_superheroes&cmstartsortkeyprefix=Mond&cmlimit=5000&format=json'
address2 = 'http://en.wikipedia.org/w/api.php?action=query&list=categorymembers&cmtitle=Category:Marvel_Comics_supervillains&cmstartsortkeyprefix=Sent&cmlimit=5000&format=json'
response1 = wiki_to_json_dict(address1)
response2 = wiki_to_json_dict(address2)
superheroes = get_category_members(response1)
supervillains = get_category_members(response2)

#for element in superheroes:
 #   title = extract_category_member_title(element)
  #  download_page_and_save_to_file(title, 'heroes')

for element in supervillains:
    title = extract_category_member_title(element)
    download_page_and_save_to_file(title, 'villains')

# %% [markdown]
# ###### Maintain lists of: pure heroes (the “good”), pure villains (the “bad”) and both (the “neutral”)

# %%
#cleans up a filename
def clean_filename(name):
        name = name.replace(' (comics)', '')
        name = name.replace(' (Marvel Comics)', '')
        return name

#reads filenames in a location and cleans them up
def read_hero_names(location):
    import os
    path = os.path.join(location)
    files = os.listdir(path)
    hero_names = []
    for file_name in files:
        hero_names.append(clean_filename(file_name))
    return hero_names

#populates datastructures holding the characters names and information
def populate_hero_dictionary_and_lists(locations):
    import os
    import json
    hero_dict = dict()
    good = set()
    bad = set()
    neutral = set()
    for location in locations:
        path = os.path.join(location)
        files = os.listdir(path)
        for file_name in files:
            file_contents = open(path + '/' + file_name, 'r')
            json_contents = json.load(file_contents)
            file_name = clean_filename(file_name)
            if location == 'heroes':
                good.add(file_name)
            else:
                bad.add(file_name)
            if file_name not in hero_dict:
                hero_dict[file_name] = json_contents
            else:
                neutral.add(file_name)
    return (hero_dict, good, bad, neutral)

#folders with text files
path1 = 'heroes'
path2 = 'villains'

#Dictionary for all heroes names and the text of their pages; lists of names for the heroes of each category
all_heroes, the_good, the_bad, the_neutral = populate_hero_dictionary_and_lists([path1, path2])
len(the_good), len(the_bad), len(the_neutral)
# Out:
# (915, 1261, 167)

# %% [markdown]
# ## Excercise A2: Prepare the wikipedia text for Bag of Words (BoW) analysis

# %%
#extract text from json structure
def extract_text_from_article(structure):
    pageid = list(structure['query']['pages'].keys())[0]
    return (structure['query']['pages'][pageid]['revisions'])[0]['*']

#remove special chars, formatting, numbers and alternative links
def clean_up_data(data):
    to_remove = ['\n', '(', ')', '{', '}', '<br/>', '<br>', '=', '#', '*' 
                 '<ref>', '</ref>', '\'', '"', '<', '>', '!', '?', '-', ',', '.', ':']
    for character in to_remove:
        data = data.replace(character, '')
    import re
    regex = '\|[\w|\s]+?\]\]'
    data = re.sub(regex, '', data)
    data = re.sub('\d+', '', data)
    to_remove2 = ['[', ']', '|']
    for character in to_remove2:
        data = data.replace(character, '')
    return data

# %% [markdown]
# ## Excercise A3: Quality control

# %%
#Page is rejected if it is a redirect, a stub or very short
def is_acceptable(page):
    return not (page.startswith('#REDIRECT') or '{{Marvel-villain-stub}}' in page or len(page) < 1500)

#discard unacceptable articles and clean up data
clean_data = dict()
for hero in all_heroes.keys():
    data = extract_text_from_article(all_heroes[hero])
    if is_acceptable(data):
        clean_data[hero] = clean_up_data(data)
    else:
        the_bad.discard(hero)
        the_good.discard(hero)
        the_neutral.discard(hero)
len(the_good), len(the_bad), len(the_neutral)
# Out:
# (855, 949, 161)

# %% [markdown]
# ## BoW Generation

# %% [markdown]
# ## Excercise A4: Getting ANEW data

# %% [markdown]
# ###### How many words are in the ANEW vocabulary?

# %% [markdown]
# 13915

# %% [markdown]
# ###### Read the values into a Python dict.

# %%
import csv
csvfile = open('Ratings_Warriner_et_al.csv', 'r')
reader = csv.DictReader(csvfile)

ANEW_data = {}
for row in reader:
    word, valence, arousal, dominance = row['Word'], row['V.Mean.Sum'], row['A.Mean.Sum'], row['D.Mean.Sum']
    ANEW_word = [valence, arousal, dominance]
    ANEW_word = [round(float(el) - 5, 2) for el in ANEW_word]
    ANEW_data[word] = ANEW_word

# %% [markdown]
# ## Excercise A5: Vectorizing

# %% [markdown]
# ###### Make sure you understand what the vocabulary keyword parameter does. Write a short explanation in your own words

# %% [markdown]
# Stores mapping from word to column it is stored in. e.g. vectorizer.vocabulary_.get('dead') gives column 2134.

# %% [markdown]
# ###### Vectorize the pages for all Marvel characters. Only keep track of words found in the ANEW data set.

# %%
#removes words that are not in ANEW file
def remove_data_not_in_ANEW(data):
    temp_data = []
    for element in data.split():
        if element in ANEW_data:
            temp_data.append(element)
    return ' '.join(temp_data)

from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(min_df=1)

relevant_words_only = {}
for hero in clean_data.keys():
    relevant_words_only[hero] = remove_data_not_in_ANEW(clean_data[hero])
cleaned_article_words = list(relevant_words_only.values())

vectorized_data = vectorizer.fit_transform(cleaned_article_words)

# %% [markdown]
# ###### You now have a matrix X. Let’s make sure we understand it.
#
#     What shape is it? (What are the dimensions)
#     What do rows correspond to?
#     What do columns correspond to?
#     How do you relate a single Marvel character to the elements in X?
#     How do you relate the vocabulary from the ANEW data set to the elements in X?

# %% [markdown]
# 1637 rows x 9479 columns
# Rows: Each document (character)
# Columns: Each ANEW word found in the documents (0 if not found, 1 or more if found)

# %% [markdown]
# # Part B. Calculate Sentiment scores

# %%
import numpy as np
def put_relevant_ANEW_words_in_matrix(vect_names):
    data_list = []
    for name in vectorizer_names:
        try:
            ANEW_score = ANEW_data[name]
        except KeyError:
                try:
                    ANEW_score = ANEW_data[name.capitalize()]
                except KeyError:
                    ANEW_score = ANEW_data[name.upper()]
        finally:
            data_list.append(ANEW_score)
    return np.array(data_list)

order_of_heros_in_matrix = list(relevant_words_only.keys()) #ordered list of articles present in vectorizer
vectorizer_names = vectorizer.get_feature_names() #list of words in vectorizer
X = vectorized_data.toarray() #get rid of sparse matrix format
number_of_ANEW_words_in_articles = X.sum(axis=1)[:,None] #sum each row of word freq matrix, add extra dimension for numpy's sake
W = put_relevant_ANEW_words_in_matrix(vectorizer_names) #populate a matrix with ANEW values which occurred in the text (vectorizer)

# %%
Z_sum = np.dot(X, W) #calculate dot product of word frequency matrix and ANEW weights matrix
Z_sum
# Out:
# array([[ 504.7 , -574.67,  434.54],
#        [  74.1 , -142.46,   64.  ],
#        [ 130.73, -291.55,  172.01],
#        ...,
#        [  93.63, -112.34,   86.81],
#        [ 214.15, -256.  ,  177.45],
#        [ 342.46, -534.75,  304.49]])

# %% [markdown]
# ###### Write down the shapes of W, X and Z

# %% [markdown]
# X: (1637, 9479)
# W: (9479, 3)
# Z: (1637, 3)

# %%
Z_mean = Z_sum / number_of_ANEW_words_in_articles #divide the summed scores by the total number of ANEW words in respective articles
Z_mean
# Out:
# array([[ 0.65122581, -0.74150968,  0.56069677],
#        [ 0.50067568, -0.96256757,  0.43243243],
#        [ 0.37566092, -0.83778736,  0.49428161],
#        ...,
#        [ 0.54121387, -0.64936416,  0.50179191],
#        [ 0.67131661, -0.80250784,  0.55626959],
#        [ 0.55957516, -0.87377451,  0.49753268]])

# %% [markdown]
# # Part C. Plot your results

# %% [markdown]
# ## Exercise C1: Character comparison

# %% [markdown]
# ###### Create script that takes sentiment_scores, 2 character names and plots their ANEW scores

# %%
#plot 2 character's ANEW scores as neighbouring bar charts
def plot_ANEW_scores(character1, character2, sentiment_scores, article_order):
    index1 = article_order.index(character1)
    index2 = article_order.index(character2)
    ANEW_char1 = sentiment_scores[index1,]
    ANEW_char2 = sentiment_scores[index2,]
    import matplotlib.pyplot as plt
    n_groups = 3
    means_men = ANEW_char1
    means_women = ANEW_char2
    fig, ax = plt.subplots()
    index = np.arange(n_groups)
    bar_width = 0.35
    opacity = 0.4
    rects1 = plt.bar(index, means_men, bar_width,
                 alpha=opacity,
                 color='b',
                 label=character1)
    rects2 = plt.bar(index + bar_width, means_women, bar_width,
                 alpha=opacity,
                 color='r',
                 label=character2)
    plt.xlabel('Parameter')
    plt.ylabel('ANEW value')
    plt.title('ANEW scores')
    plt.xticks(index + bar_width, ('Valence', 'Arousal', 'Dominance'))
    plt.legend(bbox_to_anchor=(1, 1), loc=3, borderaxespad=0.)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ###### Use your plot to investigate differences between: “Magneto” or “Professor X”.

# %%
plot_ANEW_scores('Magneto', 'Professor X', Z_mean, order_of_heros_in_matrix)

# %% [markdown]
# ###### Describe your findings in your own words.

# %% [markdown]
# Both characters have a positive value for valence and dominance, while having a negative arousal score. Professor X's scores are significantly higher/lower than Magneto's in their respective ANEW parameters - it could signify that Professor X polarizes sentiments more than Magneto. In general, the findings show that both characters are associated with happy emotions (high valence) and power (high dominance). They both would seem to score low on the strength of arousal evoked, however.

# %% [markdown]
# ## Exercise C2: Scatter plots

# %% [markdown]
# ###### Create three scatter plots, where the dots are characters from each group (‘good’, ‘bad’, ‘neutral’), with a distinct plot symbol per group.

# %%
#Draws a scatter plot with average lines for chosen two ANEW values for provided good, bad and neutral characters
def draw_scatter_plot_for_many_characters(good_chars, bad_chars, neutral_chars, sentiment_scores, article_order, graph_type):
    import matplotlib.pyplot as plt
    import numpy as np
    def extract_single_ANEW_values(characters):
        t_valence = []
        t_arousal = []
        t_dominance = []
        for character in characters:
            index = article_order.index(character)
            sentiment = sentiment_scores[index,]
            t_valence.append(sentiment[0])
            t_arousal.append(sentiment[1])
            t_dominance.append(sentiment[2])
        return (t_valence, t_arousal, t_dominance)
    good_valence, good_arousal, good_dominance = extract_single_ANEW_values(good_chars)
    bad_valence, bad_arousal, bad_dominance = extract_single_ANEW_values(bad_chars)
    neutral_valence, neutral_arousal, neutral_dominance = extract_single_ANEW_values(neutral_chars)
    valences = good_valence + bad_valence + neutral_valence
    arousals = good_arousal + bad_arousal + neutral_arousal
    dominances = good_dominance + bad_dominance + neutral_dominance
    valence_av = np.average(valences)
    arousal_av = np.average(arousals)
    dominance_av = np.average(dominances)
    plt.figure(figsize=(8, 6), dpi=80)
    if graph_type == 'VA':
        x_min, x_max = min(valences)-0.1, max(valences)+0.1
        y_min, y_max = min(arousals)-0.1, max(arousals)+0.1
        plt.xlim(x_min,x_max)
        plt.ylim(y_min, y_max)
        plt.scatter(good_valence, good_arousal, marker='o', color='green', alpha=0.5, label='Good')
        plt.scatter(bad_valence, bad_arousal, marker='x', color='red', alpha=0.5, label='Bad')
        plt.scatter(neutral_valence, neutral_arousal, marker='v', color='blue', alpha=0.5, label='Neutral')
        plt.plot([valence_av, valence_av], [y_min, y_max], color='orange', linewidth=1.5, linestyle="--", label='Valence average')
        plt.plot([x_min, x_max], [arousal_av, arousal_av], color='purple', linewidth=1.5, linestyle="--", label='Arousal average')
        plt.title("Valence vs Arousal")
        plt.xlabel("Valence", size=20)
        plt.ylabel("Arousal", size=20)
    elif graph_type == 'VD':
        x_min, x_max = min(valences)-0.1, max(valences)+0.1
        y_min, y_max = min(dominances)-0.1, max(dominances)+0.1
        plt.xlim(x_min,x_max)
        plt.ylim(y_min, y_max)
        plt.scatter(good_valence, good_dominance, marker='o', color='green', alpha=0.5, label='Good')
        plt.scatter(bad_valence, bad_dominance, marker='x', color='red', alpha=0.5, label='Bad')
        plt.scatter(neutral_valence, neutral_dominance, marker='v', color='blue', alpha=0.5, label='Neutral')
        plt.plot([valence_av, valence_av], [y_min, y_max], color='orange', linewidth=1.5, linestyle="--", label='Valence average')
        plt.plot([x_min, x_max], [dominance_av, dominance_av], color='purple', linewidth=1.5, linestyle="--", label='Dominance average')
        plt.title("Valence vs Dominance")
        plt.xlabel("Valence", size=20)
        plt.ylabel("Dominance", size=20)
    elif graph_type == 'AD':
        x_min, x_max = min(arousals)-0.1, max(arousals)+0.1
        y_min, y_max = min(dominances)-0.1, max(dominances)+0.1
        plt.xlim(x_min,x_max)
        plt.ylim(y_min, y_max)
        plt.scatter(good_arousal, good_dominance, marker='o', color='green', alpha=0.5, label='Good')
        plt.scatter(bad_arousal, bad_dominance, marker='x', color='red', alpha=0.5, label='Bad')
        plt.scatter(neutral_arousal, neutral_dominance, marker='v', color='blue', alpha=0.5, label='Neutral')
        plt.plot([arousal_av, arousal_av], [y_min, y_max], color='orange', linewidth=1.5, linestyle="--", label='Arousal average')
        plt.plot([x_min, x_max], [dominance_av, dominance_av], color='purple', linewidth=1.5, linestyle="--", label='Dominance average')
        plt.title("Arousal vs Dominance")
        plt.xlabel("Arousal", size=20)
        plt.ylabel("Dominance", size=20)
    else:
        raise ValueError('Invalid input')    
    plt.grid(True)
    plt.legend(bbox_to_anchor=(1, 1), loc=3, borderaxespad=0.)
    plt.show()
draw_scatter_plot_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'VA')
draw_scatter_plot_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'VD')
draw_scatter_plot_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'AD')

# %% [markdown]
# ###### What did you learn from the scatter plots?

# %% [markdown]
# Good characters tend to have higher dominance than bad bad characters, while bad characters tend to evoke more arousal. Similarly, bad characters have much lower valence values than good characters. Neutral characters are mostly neatly placed in the mid-range values. There is significant clustering around average values, but some outliers are present as well.

# %% [markdown]
# ## Exercise C3: Histograms

# %% [markdown]
# ###### Create normalized histograms of the values found for Valence (for Good, Bad, Neutral), Arousal (for Good, Bad, Neutral), Dominance (for Good, Bad, Neutral)

# %%
#Draws a histogram for a given ANEW value for provided good, bad and neutral characters
def draw_histogram_for_many_characters(good_chars, bad_chars, neutral_chars, sentiment_scores, article_order, graph_type):
    import matplotlib.pyplot as plt
    import numpy as np
    def extract_single_ANEW_values(characters):
        t_valence = []
        t_arousal = []
        t_dominance = []
        for character in characters:
            index = article_order.index(character)
            sentiment = sentiment_scores[index,]
            t_valence.append(sentiment[0])
            t_arousal.append(sentiment[1])
            t_dominance.append(sentiment[2])
        return (t_valence, t_arousal, t_dominance)
    good_valence, good_arousal, good_dominance = extract_single_ANEW_values(good_chars)
    bad_valence, bad_arousal, bad_dominance = extract_single_ANEW_values(bad_chars)
    neutral_valence, neutral_arousal, neutral_dominance = extract_single_ANEW_values(neutral_chars)
    valences = good_valence + bad_valence + neutral_valence
    arousals = good_arousal + bad_arousal + neutral_arousal
    dominances = good_dominance + bad_dominance + neutral_dominance
    plt.figure(figsize=(8, 6), dpi=80)
    bins = numpy.linspace(-1, 2, 50)
    plt.title(graph_type)
    plt.xlabel("Value", size=20)
    plt.ylabel("Frequency", size=20)
    if graph_type == 'Valence':
        x_min, x_max = min(valences)-0.1, max(valences)+0.1
        plt.xlim(x_min,x_max)
        plt.hist(neutral_valence, bins, alpha=0.5, normed=True, label='Neutral')
        plt.hist(good_valence, bins, alpha=0.5, normed=True, label='Good')
        plt.hist(bad_valence, bins, alpha=0.5, normed=True, label='Bad')
    elif graph_type == 'Arousal':
        x_min, x_max = min(arousals)-0.1, max(arousals)+0.1
        plt.xlim(x_min,x_max)
        plt.hist(neutral_arousal, bins, alpha=0.5, normed=True, label='Neutral')
        plt.hist(good_arousal, bins, alpha=0.5, normed=True, label='Good')
        plt.hist(bad_arousal, bins, alpha=0.5, normed=True, label='Bad')
    elif graph_type == 'Dominance':
        x_min, x_max = min(dominances)-0.1, max(dominances)+0.1
        plt.xlim(x_min,x_max)
        plt.hist(neutral_dominance, bins, alpha=0.5, normed=True, label='Neutral')
        plt.hist(good_dominance, bins, alpha=0.5, normed=True, label='Good')
        plt.hist(bad_dominance, bins, alpha=0.5, normed=True, label='Bad')
    else:
        raise ValueError('Invalid input')
    plt.grid(True)
    plt.legend(bbox_to_anchor=(1, 1), loc=3, borderaxespad=0.)
    plt.show()
draw_histogram_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'Valence')
draw_histogram_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'Arousal')
draw_histogram_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'Dominance')

# %%
#Draws histograms for all ANEW values for provided good, bad and neutral characters
def draw_histograms_for_many_characters(good_chars, bad_chars, neutral_chars, sentiment_scores, article_order):
    import matplotlib.pyplot as plt
    import numpy as np
    def extract_single_ANEW_values(characters):
        t_valence = []
        t_arousal = []
        t_dominance = []
        for character in characters:
            index = article_order.index(character)
            sentiment = sentiment_scores[index,]
            t_valence.append(sentiment[0])
            t_arousal.append(sentiment[1])
            t_dominance.append(sentiment[2])
        return (t_valence, t_arousal, t_dominance)
    good_valence, good_arousal, good_dominance = extract_single_ANEW_values(good_chars)
    bad_valence, bad_arousal, bad_dominance = extract_single_ANEW_values(bad_chars)
    neutral_valence, neutral_arousal, neutral_dominance = extract_single_ANEW_values(neutral_chars)
    valences = good_valence + bad_valence + neutral_valence
    arousals = good_arousal + bad_arousal + neutral_arousal
    dominances = good_dominance + bad_dominance + neutral_dominance
    fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15, 8))
    bins = 50
    ax0.hist(neutral_valence, bins, alpha=0.5, normed=True, label='Neutral')
    ax0.hist(good_valence, bins, alpha=0.5, normed=True, label='Good')
    ax0.hist(bad_valence, bins, alpha=0.5, normed=True, label='Bad')
    ax0.set_xlabel('Value')
    ax0.set_ylabel('Frequency')
    ax0.set_title('Valence', size=20)
    ax0.grid(True)
    ax0.legend()
    ax1.hist(neutral_arousal, bins, alpha=0.5, normed=True, label='Neutral')
    ax1.hist(good_arousal, bins, alpha=0.5, normed=True, label='Good')
    ax1.hist(bad_arousal, bins, alpha=0.5, normed=True, label='Bad')
    ax1.set_xlabel('Value')
    ax1.set_ylabel('Frequency')
    ax1.set_title('Arousal', size=20)
    ax1.grid(True)
    ax1.legend()
    ax2.hist(neutral_dominance, bins, alpha=0.5, normed=True, label='Neutral')
    ax2.hist(good_dominance, bins, alpha=0.5, normed=True, label='Good')
    ax2.hist(bad_dominance, bins, alpha=0.5, normed=True, label='Bad')
    ax2.set_xlabel('Value')
    ax2.set_ylabel('Frequency')
    ax2.set_title('Dominance', size=20)
    ax2.grid(True)
    ax2.legend()
    plt.tight_layout()
    plt.show()
draw_histograms_for_many_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix)

# %% [markdown]
# ###### What did you learn from the histograms?

# %% [markdown]
# Bad characters generally have lower valence, higher arousal and lower dominance than good characters.

# %% [markdown]
# ## Exercise C1: Thresholding

# %% [markdown]
# ###### Look at the histograms from the previous exercise. Which of the axes does the best job of discriminating between good and bad?

# %% [markdown]
# x axis, since it holds the absolute values achieved. y axis merely shows the frequency of each bin.

# %% [markdown]
# ###### Chose one of the 3 ANEW features to be used for classifying. Find a suitable cutoff point. all characters with a score above this will be classified as “good”, all below is “bad”.

# %% [markdown]
# Valence, cutoff at 0.6: lower - bad, higher - good.

# %% [markdown]
# ###### Using this simple classifier, what is the accuracy and error rate?
#
#     accuracy = (hit) / (hit + miss)
#     error_rate = (miss) / (hit + miss)

# %%
#Classifies characters based on one feature and single cutoff. Returns accuracy rates for classification
def classify_characters(good_chars, bad_chars, neutral_chars, sentiment_scores, article_order, feature, cutoff):
    def extract_single_ANEW_values(characters):
        t_valence = []
        t_arousal = []
        t_dominance = []
        for character in characters:
            index = article_order.index(character)
            sentiment = sentiment_scores[index,]
            t_valence.append(sentiment[0])
            t_arousal.append(sentiment[1])
            t_dominance.append(sentiment[2])
        return (t_valence, t_arousal, t_dominance)
    good_valence, good_arousal, good_dominance = extract_single_ANEW_values(good_chars)
    bad_valence, bad_arousal, bad_dominance = extract_single_ANEW_values(bad_chars)
    neutral_valence, neutral_arousal, neutral_dominance = extract_single_ANEW_values(neutral_chars)
    rates = {}
    if feature == 'Valence':
        hits_good = sum(num >= cutoff for num in good_valence)
        misses_good = sum(num <= cutoff for num in good_valence)
        hit_rate_good = hits_good / (hits_good + misses_good)
        error_rate_good = misses_good / (hits_good + misses_good)
        rates['Hit/error rate good'] = (round(float(hit_rate_good),3), round(float(error_rate_good),3))
        hits_bad = sum(num <= cutoff for num in bad_valence)
        misses_bad = sum(num >= cutoff for num in bad_valence)
        hit_rate_bad = hits_bad / (hits_bad + misses_bad)
        error_rate_bad = misses_bad / (hits_bad + misses_bad)
        rates['Hit/error rate bad'] = (round(float(hit_rate_bad),3), round(float(error_rate_bad),3))
        hit_rate_total = (hits_good + hits_bad) / (hits_good + misses_good + hits_bad + misses_bad)
        error_rate_total = (misses_bad + misses_good) / (hits_bad + misses_bad + hits_good + misses_good)  
        rates['Hit/error rate total'] = (round(float(hit_rate_total), 3), round(float(error_rate_total),3))
    else: #cases for arousal and dominance should be here
        raise ValueError('Not implemented yet')
    return rates
classifier_rates = classify_characters(the_good, the_bad, the_neutral, Z_mean, order_of_heros_in_matrix, 'Valence',  0.6)
print (classifier_rates)
# Out:
# {'Hit/error rate bad': (0.702, 0.298), 'Hit/error rate total': (0.654, 0.346), 'Hit/error rate good': (0.6, 0.4)}

# %% [markdown]
# ###### How well does this perform?

# %%
number_good = len(the_good)
number_bad = len(the_bad)
random_chance_good = round(float(number_good / (number_bad + number_good)), 3)
random_chance_bad = round(float(number_bad / (number_good + number_bad)),3)
print ('Random chance of picking good character:', random_chance_good)
print ('Random chance of picking badd character:', random_chance_bad)
# Out:
# Random chance of picking good character: 0.474
# Random chance of picking badd character: 0.526

# %% [markdown]
# Performs reasonably well, at between 60% and 70% accuracy. This is a significant improvement over the random chances of picking respective characters.

# %% [markdown]
# ###### Why isn’t it performing better?

# %% [markdown]
# Only single feature is included (valence, in this case) and the cutoff point is a fixed constant. More accuracy could probably be achieved by considering all three features, each with its own fixed cutoff or possibly with variable cutoff points (depending on data).
